# %%
 graph = {
        "s1": {"s2": 2, "s10": 1, "s12": 4, "s5": 3},
        "s2": {"s1": 1, "s10": 4, "s12": 2, "s5": 2},
        "s10": {"s1": 2, "s2": 1, "s12": 1, "s5": 4},
        "s12": {"s1": 3, "s2": 5, "s10": 2, "s5": 1},
        "s5": {"s1": 3, "s2": 5, "s10": 2, "s12": 4}
        }
 
 distance_graph = {node: float("inf") for node in graph}
 print(distance_graph)
# Out:
# {'s1': inf, 's2': inf, 's10': inf, 's12': inf, 's5': inf}
